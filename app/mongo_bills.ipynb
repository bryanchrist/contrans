# %%
import numpy as np
import pandas as pd
import pymongo
import requests
import os 
from bson.json_util import loads, dumps

# %%
propublica_token = os.environ['propublica_token']
mongo_user = os.environ['MONGO_INITDB_ROOT_USERNAME']
mongo_pwd= os.environ['MONGO_INITDB_ROOT_PASSWORD']
mongo_initdb = os.environ['MONGO_INITDB_DATABASE']

# %%
import get_data

# %%
useragent= get_data.get_useragent()
useragent
# Out:
# 'python-requests/2.28.1'

# %%
bills_list, num_results = get_data.get_bills_pp(propublica_token, useragent, email = 'brc4cb@virginia.edu', offset = 0 )

# %%
bills_list
# Out:
# [{'bill_id': 'sres830-117',
#   'bill_slug': 'sres830',
#   'bill_type': 'sres',
#   'number': 'S.RES.830',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/sres830.json',
#   'title': 'A resolution expressing support for the designation of the week of October 24, 2022, to October 31, 2022, as "Bat Week".',
#   'short_title': 'A resolution expressing support for the designation of the week of October 24, 2022, to October 31, 2022, as "Bat Week".',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'L000174',
#   'sponsor_name': 'Patrick J. Leahy',
#   'sponsor_state': 'VT',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000174.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-resolution/830',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/sres830',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'D': 1},
#   'committees': 'Senate Environment and Public Works Committee',
#   'committee_codes': ['SSEV'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the Committee on Environment and Public Works.'},
#  {'bill_id': 's5082-117',
#   'bill_slug': 's5082',
#   'bill_type': 's',
#   'number': 'S.5082',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5082.json',
#   'title': 'A bill to impose sanctions with respect to General Secretary Xi Jinping and other senior officials of the Chinese Communist Party complicit in the perpetration of genocide and other crimes against humanity against Uyghurs and other ethnic minorities in the Xinjiang Uyghur Autonomous Region.',
#   'short_title': 'A bill to impose sanctions with respect to General Secretary Xi Jinping and other senior officials of the Chinese Communist Party complicit in the perpetration of genocide and other crimes against humanity against Uyghurs and other ethnic minorities in th',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'H001089',
#   'sponsor_name': 'Joshua Hawley',
#   'sponsor_state': 'MO',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/H001089.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5082',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5082',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'Senate Foreign Relations Committee',
#   'committee_codes': ['SSFR'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Foreign Relations.'},
#  {'bill_id': 's5077-117',
#   'bill_slug': 's5077',
#   'bill_type': 's',
#   'number': 'S.5077',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5077.json',
#   'title': 'A bill to amend the Alaska Native Claims Settlement Act to provide that Alexander Creek, Incorporated, is recognized as a Village Corporation under that Act, and for other purposes.',
#   'short_title': 'A bill to amend the Alaska Native Claims Settlement Act to provide that Alexander Creek, Incorporated, is recognized as a Village Corporation under that Act, and for other purposes.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'S001198',
#   'sponsor_name': 'Dan Sullivan',
#   'sponsor_state': 'AK',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/S001198.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5077',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5077',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'Senate Energy and Natural Resources Committee',
#   'committee_codes': ['SSEG'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#  {'bill_id': 's5081-117',
#   'bill_slug': 's5081',
#   'bill_type': 's',
#   'number': 'S.5081',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5081.json',
#   'title': 'A bill to establish an Office of Environmental Justice within the Department of Justice, and for other purposes.',
#   'short_title': 'A bill to establish an Office of Environmental Justice within the Department of Justice, and for other purposes.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'P000145',
#   'sponsor_name': 'Alex Padilla',
#   'sponsor_state': 'CA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/P000145.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5081',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5081',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 7,
#   'cosponsors_by_party': {'D': 6, 'ID': 1},
#   'committees': 'Senate Judiciary Committee',
#   'committee_codes': ['SSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on the Judiciary.'},
#  {'bill_id': 's5079-117',
#   'bill_slug': 's5079',
#   'bill_type': 's',
#   'number': 'S.5079',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5079.json',
#   'title': 'A bill to designate the facility of the United States Postal Service located at 202 2nd Avenue in Oklee, Minnesota, as the "Coya Knutson Post Office".',
#   'short_title': 'A bill to designate the facility of the United States Postal Service located at 202 2nd Avenue in Oklee, Minnesota, as the "Coya Knutson Post Office".',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'K000367',
#   'sponsor_name': 'Amy Klobuchar',
#   'sponsor_state': 'MN',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/K000367.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5079',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5079',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'D': 1},
#   'committees': 'Senate Homeland Security and Governmental Affairs Committee',
#   'committee_codes': ['SSGA'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': 'Designates the facility of the United States Postal Service located at 202 2nd Avenue in Oklee, Minnesota, as the "Coya Knutson Post Office."',
#   'summary_short': 'Designates the facility of the United States Postal Service located at 202 2nd Avenue in Oklee, Minnesota, as the &quot;Coya Knutson Post Office.&quot;',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#  {'bill_id': 's5076-117',
#   'bill_slug': 's5076',
#   'bill_type': 's',
#   'number': 'S.5076',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5076.json',
#   'title': 'A bill to require training for employees of Federal agencies that award less than 3 percent of prime contracts to small business concerns owned and controlled by service-disabled veterans, and for other purposes.',
#   'short_title': 'A bill to require training for employees of Federal agencies that award less than 3 percent of prime contracts to small business concerns owned and controlled by service-disabled veterans, and for other purposes.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'E000295',
#   'sponsor_name': 'Joni Ernst',
#   'sponsor_state': 'IA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/E000295.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5076',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5076',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 2,
#   'cosponsors_by_party': {'D': 1, 'R': 1},
#   'committees': 'Senate Small Business and Entrepreneurship Committee',
#   'committee_codes': ['SSSB'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Small Business and Entrepreneurship.'},
#  {'bill_id': 's5080-117',
#   'bill_slug': 's5080',
#   'bill_type': 's',
#   'number': 'S.5080',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5080.json',
#   'title': 'A bill to direct the Secretary of Transportation to promulgate a Federal motor vehicle safety standard to reduce the incidence of child injury and death occurring during low-speed incidents involving motor vehicles, and for other purposes.',
#   'short_title': 'A bill to direct the Secretary of Transportation to promulgate a Federal motor vehicle safety standard to reduce the incidence of child injury and death occurring during low-speed incidents involving motor vehicles, and for other purposes.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'B001277',
#   'sponsor_name': 'Richard Blumenthal',
#   'sponsor_state': 'CT',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/B001277.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5080',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5080',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'Senate Commerce, Science, and Transportation Committee',
#   'committee_codes': ['SSCM'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#  {'bill_id': 's5084-117',
#   'bill_slug': 's5084',
#   'bill_type': 's',
#   'number': 'S.5084',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5084.json',
#   'title': 'A bill to reprioritize Federal law enforcement funds from prosecuting nonviolent pro-life demonstrators to prosecuting violent offenders and drug traffickers.',
#   'short_title': 'A bill to reprioritize Federal law enforcement funds from prosecuting nonviolent pro-life demonstrators to prosecuting violent offenders and drug traffickers.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'H000601',
#   'sponsor_name': 'Bill Hagerty',
#   'sponsor_state': 'TN',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/H000601.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5084',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5084',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 5,
#   'cosponsors_by_party': {'R': 5},
#   'committees': 'Senate Judiciary Committee',
#   'committee_codes': ['SSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on the Judiciary.'},
#  {'bill_id': 's5083-117',
#   'bill_slug': 's5083',
#   'bill_type': 's',
#   'number': 'S.5083',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5083.json',
#   'title': 'A bill to require the Secretary of State to submit an annual report to Congress regarding the ties between criminal gangs and political and economic elites in Haiti.',
#   'short_title': 'A bill to require the Secretary of State to submit an annual report to Congress regarding the ties between criminal gangs and political and economic elites in Haiti.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'M000639',
#   'sponsor_name': 'Robert Menendez',
#   'sponsor_state': 'NJ',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/M000639.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5083',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5083',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 2,
#   'cosponsors_by_party': {'R': 1, 'D': 1},
#   'committees': 'Senate Foreign Relations Committee',
#   'committee_codes': ['SSFR'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Foreign Relations.'},
#  {'bill_id': 's5085-117',
#   'bill_slug': 's5085',
#   'bill_type': 's',
#   'number': 'S.5085',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5085.json',
#   'title': 'A bill to prohibit the government of the District of Columbia from using Federal funds to allow individuals who are not citizens of the United States to vote in any election. and for other purposes.',
#   'short_title': 'A bill to prohibit the government of the District of Columbia from using Federal funds to allow individuals who are not citizens of the United States to vote in any election. and for other purposes.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'C001098',
#   'sponsor_name': 'Ted Cruz',
#   'sponsor_state': 'TX',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001098.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5085',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5085',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'Senate Homeland Security and Governmental Affairs Committee',
#   'committee_codes': ['SSGA'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#  {'bill_id': 's5078-117',
#   'bill_slug': 's5078',
#   'bill_type': 's',
#   'number': 'S.5078',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5078.json',
#   'title': 'A bill to designate the facility of the United States Postal Service located at 123 East Main Street in Vergas, Minnesota, as the "Jon Glawe Post Office".',
#   'short_title': 'A bill to designate the facility of the United States Postal Service located at 123 East Main Street in Vergas, Minnesota, as the "Jon Glawe Post Office".',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'K000367',
#   'sponsor_name': 'Amy Klobuchar',
#   'sponsor_state': 'MN',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/K000367.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5078',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5078',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'D': 1},
#   'committees': 'Senate Homeland Security and Governmental Affairs Committee',
#   'committee_codes': ['SSGA'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': 'Designates the facility of the United States Postal Service located at 123 East Main Street in Vergas, Minnesota, as the "Jon Glawe Post Office."',
#   'summary_short': 'Designates the facility of the United States Postal Service located at 123 East Main Street in Vergas, Minnesota, as the &quot;Jon Glawe Post Office.&quot;',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#  {'bill_id': 'sjres64-117',
#   'bill_slug': 'sjres64',
#   'bill_type': 'sjres',
#   'number': 'S.J.RES.64',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/sjres64.json',
#   'title': 'A joint resolution disapproving of the rule submitted by the Department of Homeland Security relating to "Public Charge Ground of Inadmissibility".',
#   'short_title': 'A joint resolution disapproving of the rule submitted by the Department of Homeland Security relating to "Public Charge Ground of Inadmissibility".',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'M001198',
#   'sponsor_name': 'Roger Marshall',
#   'sponsor_state': 'KS',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/M001198.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-joint-resolution/64',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/sjres64',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'R': 1},
#   'committees': 'Senate Judiciary Committee',
#   'committee_codes': ['SSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on the Judiciary.'},
#  {'bill_id': 'hr9295-117',
#   'bill_slug': 'hr9295',
#   'bill_type': 'hr',
#   'number': 'H.R.9295',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9295.json',
#   'title': 'To amend the Alaska Native Claims Settlement Act to provide that Alexander Creek, Incorporated, is recognized as a Village Corporation under that Act, and for other purposes.',
#   'short_title': 'To amend the Alaska Native Claims Settlement Act to provide that Alexander Creek, Incorporated, is recognized as a Village Corporation under that Act, and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'P000619',
#   'sponsor_name': 'Mary Peltola',
#   'sponsor_state': 'AK',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/P000619.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9295',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9295',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Natural Resources Committee',
#   'committee_codes': ['HSII'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Natural Resources.'},
#  {'bill_id': 'hr9294-117',
#   'bill_slug': 'hr9294',
#   'bill_type': 'hr',
#   'number': 'H.R.9294',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9294.json',
#   'title': "To amend the Claims Resolution Act to make a technical correction to the Taos Pueblo Water Development Fund and the Aamodt Settlement Pueblos' Fund, and for other purposes.",
#   'short_title': "To amend the Claims Resolution Act to make a technical correction to the Taos Pueblo Water Development Fund and the Aamodt Settlement Pueblos' Fund, and for other purposes.",
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'L000273',
#   'sponsor_name': 'Teresa Leger Fernandez',
#   'sponsor_state': 'NM',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000273.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9294',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9294',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Natural Resources Committee',
#   'committee_codes': ['HSII'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Natural Resources.'},
#  {'bill_id': 'hr9296-117',
#   'bill_slug': 'hr9296',
#   'bill_type': 'hr',
#   'number': 'H.R.9296',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9296.json',
#   'title': 'To direct the Director of the Bureau of Prisons to conduct a comprehensive review of understaffing across the Bureau, and for other purposes.',
#   'short_title': 'To direct the Director of the Bureau of Prisons to conduct a comprehensive review of understaffing across the Bureau, and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'S001175',
#   'sponsor_name': 'Jackie Speier',
#   'sponsor_state': 'CA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/S001175.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9296',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9296',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 5,
#   'cosponsors_by_party': {'D': 3, 'R': 2},
#   'committees': 'House Judiciary Committee',
#   'committee_codes': ['HSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on the Judiciary.'},
#  {'bill_id': 'hr9292-117',
#   'bill_slug': 'hr9292',
#   'bill_type': 'hr',
#   'number': 'H.R.9292',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9292.json',
#   'title': 'To promote United States interests at the international financial institutions, and for other purposes.',
#   'short_title': 'To promote United States interests at the international financial institutions, and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'H001072',
#   'sponsor_name': 'French Hill',
#   'sponsor_state': 'AR',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/H001072.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9292',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9292',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Financial Services Committee',
#   'committee_codes': ['HSBA'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Financial Services.'},
#  {'bill_id': 'hr9291-117',
#   'bill_slug': 'hr9291',
#   'bill_type': 'hr',
#   'number': 'H.R.9291',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9291.json',
#   'title': 'To require a report on the death of Shireen Abu Akleh.',
#   'short_title': 'To require a report on the death of Shireen Abu Akleh.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001072',
#   'sponsor_name': 'André Carson',
#   'sponsor_state': 'IN',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001072.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9291',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9291',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 18,
#   'cosponsors_by_party': {'D': 18},
#   'committees': 'House Foreign Affairs Committee',
#   'committee_codes': ['HSFA'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Foreign Affairs.'},
#  {'bill_id': 'hr9293-117',
#   'bill_slug': 'hr9293',
#   'bill_type': 'hr',
#   'number': 'H.R.9293',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9293.json',
#   'title': 'To amend the Omnibus Public Land Management Act of 2009 to make a technical correction to the Navajo Nation Water Resources Development Trust Fund, and for other purposes.',
#   'short_title': 'To amend the Omnibus Public Land Management Act of 2009 to make a technical correction to the Navajo Nation Water Resources Development Trust Fund, and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'L000273',
#   'sponsor_name': 'Teresa Leger Fernandez',
#   'sponsor_state': 'NM',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000273.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9293',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9293',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Natural Resources Committee',
#   'committee_codes': ['HSII'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Natural Resources.'},
#  {'bill_id': 'hres1465-117',
#   'bill_slug': 'hres1465',
#   'bill_type': 'hres',
#   'number': 'H.RES.1465',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hres1465.json',
#   'title': 'Amending the Rules of the House of Representatives to prohibit the consideration of bills and resolutions whose titles do not adequately express their contents.',
#   'short_title': 'Amending the Rules of the House of Representatives to prohibit the consideration of bills and resolutions whose titles do not adequately express their contents.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'D000032',
#   'sponsor_name': 'Byron Donalds',
#   'sponsor_state': 'FL',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/D000032.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-resolution/1465',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hres1465',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 2,
#   'cosponsors_by_party': {'R': 2},
#   'committees': 'House Rules Committee',
#   'committee_codes': ['HSRU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Rules.'},
#  {'bill_id': 'hres1464-117',
#   'bill_slug': 'hres1464',
#   'bill_type': 'hres',
#   'number': 'H.RES.1464',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hres1464.json',
#   'title': 'Providing for consideration of the bill (S. 4524) to limit the judicial enforceability of predispute nondisclosure and nondisparagement contract clauses relating to disputes involving sexual assault and sexual harassment; and for other purposes.',
#   'short_title': 'Providing for consideration of the bill (S. 4524) to limit the judicial enforceability of predispute nondisclosure and nondisparagement contract clauses relating to disputes involving sexual assault and sexual harassment; and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'S001205',
#   'sponsor_name': 'Mary Gay Scanlon',
#   'sponsor_state': 'PA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/S001205.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-resolution/1464',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hres1464',
#   'introduced_date': '2022-11-14',
#   'active': True,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Rules Committee',
#   'committee_codes': ['HSRU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': 'Sets forth the rule for consideration of the bill (S. 4524) to limit the judicial enforceability of predispute nondisclosure and nondisparagement contract clauses relating to disputes involving sexual assault and sexual harassment.',
#   'summary_short': 'Sets forth the rule for consideration of the bill (S. 4524) to limit the judicial enforceability of predispute nondisclosure and nondisparagement contract clauses relating to disputes involving sexual assault and sexual harassment.',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Placed on the House Calendar, Calendar No. 150.'}]

# %%
myclient = pymongo.MongoClient(f"mongodb://{mongo_user}:{mongo_pwd}@mongo:27017/{mongo_initdb}?authSource=admin")
#@mongo is whatever you named the service in your docker compose file and the port is the port you allocated in the file as well

# %%
contrans_db = myclient['contrans']
#connects to contrans if it already exists and if it doesn't it creates it (it being your mongo DB)

# %%
#go inside database and define a new collection for the bills 

collist = contrans_db.list_collection_names()
#returns all the collections currently in the DB
if "bills" in collist:
    contrans_db.bills.drop()
#gets rid of bills if it is in collections already (i.e. in the database)

# %%
#create bills collection
bills = contrans_db['bills']

# %%
#add data to mongodb- pass in bills list
bills_insert = bills.insert_many(bills_list)

# %% [markdown]
# ## Queries

# %%
#get all records
myquery = bills.find({})
loads(dumps(myquery))
#only difference between this and original list is that it creates the _id object associated with the database
# Out:
# [{'_id': ObjectId('6373b28c984f175941eafba0'),
#   'bill_id': 'sres830-117',
#   'bill_slug': 'sres830',
#   'bill_type': 'sres',
#   'number': 'S.RES.830',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/sres830.json',
#   'title': 'A resolution expressing support for the designation of the week of October 24, 2022, to October 31, 2022, as "Bat Week".',
#   'short_title': 'A resolution expressing support for the designation of the week of October 24, 2022, to October 31, 2022, as "Bat Week".',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'L000174',
#   'sponsor_name': 'Patrick J. Leahy',
#   'sponsor_state': 'VT',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000174.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-resolution/830',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/sres830',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'D': 1},
#   'committees': 'Senate Environment and Public Works Committee',
#   'committee_codes': ['SSEV'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the Committee on Environment and Public Works.'},
#  {'_id': ObjectId('6373b28c984f175941eafba1'),
#   'bill_id': 's5082-117',
#   'bill_slug': 's5082',
#   'bill_type': 's',
#   'number': 'S.5082',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5082.json',
#   'title': 'A bill to impose sanctions with respect to General Secretary Xi Jinping and other senior officials of the Chinese Communist Party complicit in the perpetration of genocide and other crimes against humanity against Uyghurs and other ethnic minorities in the Xinjiang Uyghur Autonomous Region.',
#   'short_title': 'A bill to impose sanctions with respect to General Secretary Xi Jinping and other senior officials of the Chinese Communist Party complicit in the perpetration of genocide and other crimes against humanity against Uyghurs and other ethnic minorities in th',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'H001089',
#   'sponsor_name': 'Joshua Hawley',
#   'sponsor_state': 'MO',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/H001089.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5082',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5082',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'Senate Foreign Relations Committee',
#   'committee_codes': ['SSFR'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Foreign Relations.'},
#  {'_id': ObjectId('6373b28c984f175941eafba2'),
#   'bill_id': 's5077-117',
#   'bill_slug': 's5077',
#   'bill_type': 's',
#   'number': 'S.5077',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5077.json',
#   'title': 'A bill to amend the Alaska Native Claims Settlement Act to provide that Alexander Creek, Incorporated, is recognized as a Village Corporation under that Act, and for other purposes.',
#   'short_title': 'A bill to amend the Alaska Native Claims Settlement Act to provide that Alexander Creek, Incorporated, is recognized as a Village Corporation under that Act, and for other purposes.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'S001198',
#   'sponsor_name': 'Dan Sullivan',
#   'sponsor_state': 'AK',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/S001198.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5077',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5077',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'Senate Energy and Natural Resources Committee',
#   'committee_codes': ['SSEG'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#  {'_id': ObjectId('6373b28c984f175941eafba3'),
#   'bill_id': 's5081-117',
#   'bill_slug': 's5081',
#   'bill_type': 's',
#   'number': 'S.5081',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5081.json',
#   'title': 'A bill to establish an Office of Environmental Justice within the Department of Justice, and for other purposes.',
#   'short_title': 'A bill to establish an Office of Environmental Justice within the Department of Justice, and for other purposes.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'P000145',
#   'sponsor_name': 'Alex Padilla',
#   'sponsor_state': 'CA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/P000145.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5081',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5081',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 7,
#   'cosponsors_by_party': {'D': 6, 'ID': 1},
#   'committees': 'Senate Judiciary Committee',
#   'committee_codes': ['SSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on the Judiciary.'},
#  {'_id': ObjectId('6373b28c984f175941eafba4'),
#   'bill_id': 's5079-117',
#   'bill_slug': 's5079',
#   'bill_type': 's',
#   'number': 'S.5079',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5079.json',
#   'title': 'A bill to designate the facility of the United States Postal Service located at 202 2nd Avenue in Oklee, Minnesota, as the "Coya Knutson Post Office".',
#   'short_title': 'A bill to designate the facility of the United States Postal Service located at 202 2nd Avenue in Oklee, Minnesota, as the "Coya Knutson Post Office".',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'K000367',
#   'sponsor_name': 'Amy Klobuchar',
#   'sponsor_state': 'MN',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/K000367.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5079',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5079',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'D': 1},
#   'committees': 'Senate Homeland Security and Governmental Affairs Committee',
#   'committee_codes': ['SSGA'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': 'Designates the facility of the United States Postal Service located at 202 2nd Avenue in Oklee, Minnesota, as the "Coya Knutson Post Office."',
#   'summary_short': 'Designates the facility of the United States Postal Service located at 202 2nd Avenue in Oklee, Minnesota, as the &quot;Coya Knutson Post Office.&quot;',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#  {'_id': ObjectId('6373b28c984f175941eafba5'),
#   'bill_id': 's5076-117',
#   'bill_slug': 's5076',
#   'bill_type': 's',
#   'number': 'S.5076',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5076.json',
#   'title': 'A bill to require training for employees of Federal agencies that award less than 3 percent of prime contracts to small business concerns owned and controlled by service-disabled veterans, and for other purposes.',
#   'short_title': 'A bill to require training for employees of Federal agencies that award less than 3 percent of prime contracts to small business concerns owned and controlled by service-disabled veterans, and for other purposes.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'E000295',
#   'sponsor_name': 'Joni Ernst',
#   'sponsor_state': 'IA',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/E000295.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5076',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5076',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 2,
#   'cosponsors_by_party': {'D': 1, 'R': 1},
#   'committees': 'Senate Small Business and Entrepreneurship Committee',
#   'committee_codes': ['SSSB'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Small Business and Entrepreneurship.'},
#  {'_id': ObjectId('6373b28c984f175941eafba6'),
#   'bill_id': 's5080-117',
#   'bill_slug': 's5080',
#   'bill_type': 's',
#   'number': 'S.5080',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5080.json',
#   'title': 'A bill to direct the Secretary of Transportation to promulgate a Federal motor vehicle safety standard to reduce the incidence of child injury and death occurring during low-speed incidents involving motor vehicles, and for other purposes.',
#   'short_title': 'A bill to direct the Secretary of Transportation to promulgate a Federal motor vehicle safety standard to reduce the incidence of child injury and death occurring during low-speed incidents involving motor vehicles, and for other purposes.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'B001277',
#   'sponsor_name': 'Richard Blumenthal',
#   'sponsor_state': 'CT',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/B001277.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5080',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5080',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'Senate Commerce, Science, and Transportation Committee',
#   'committee_codes': ['SSCM'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#  {'_id': ObjectId('6373b28c984f175941eafba7'),
#   'bill_id': 's5084-117',
#   'bill_slug': 's5084',
#   'bill_type': 's',
#   'number': 'S.5084',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5084.json',
#   'title': 'A bill to reprioritize Federal law enforcement funds from prosecuting nonviolent pro-life demonstrators to prosecuting violent offenders and drug traffickers.',
#   'short_title': 'A bill to reprioritize Federal law enforcement funds from prosecuting nonviolent pro-life demonstrators to prosecuting violent offenders and drug traffickers.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'H000601',
#   'sponsor_name': 'Bill Hagerty',
#   'sponsor_state': 'TN',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/H000601.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5084',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5084',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 5,
#   'cosponsors_by_party': {'R': 5},
#   'committees': 'Senate Judiciary Committee',
#   'committee_codes': ['SSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on the Judiciary.'},
#  {'_id': ObjectId('6373b28c984f175941eafba8'),
#   'bill_id': 's5083-117',
#   'bill_slug': 's5083',
#   'bill_type': 's',
#   'number': 'S.5083',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5083.json',
#   'title': 'A bill to require the Secretary of State to submit an annual report to Congress regarding the ties between criminal gangs and political and economic elites in Haiti.',
#   'short_title': 'A bill to require the Secretary of State to submit an annual report to Congress regarding the ties between criminal gangs and political and economic elites in Haiti.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'M000639',
#   'sponsor_name': 'Robert Menendez',
#   'sponsor_state': 'NJ',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/M000639.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5083',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5083',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 2,
#   'cosponsors_by_party': {'R': 1, 'D': 1},
#   'committees': 'Senate Foreign Relations Committee',
#   'committee_codes': ['SSFR'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Foreign Relations.'},
#  {'_id': ObjectId('6373b28c984f175941eafba9'),
#   'bill_id': 's5085-117',
#   'bill_slug': 's5085',
#   'bill_type': 's',
#   'number': 'S.5085',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5085.json',
#   'title': 'A bill to prohibit the government of the District of Columbia from using Federal funds to allow individuals who are not citizens of the United States to vote in any election. and for other purposes.',
#   'short_title': 'A bill to prohibit the government of the District of Columbia from using Federal funds to allow individuals who are not citizens of the United States to vote in any election. and for other purposes.',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'C001098',
#   'sponsor_name': 'Ted Cruz',
#   'sponsor_state': 'TX',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001098.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5085',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5085',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'Senate Homeland Security and Governmental Affairs Committee',
#   'committee_codes': ['SSGA'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#  {'_id': ObjectId('6373b28c984f175941eafbaa'),
#   'bill_id': 's5078-117',
#   'bill_slug': 's5078',
#   'bill_type': 's',
#   'number': 'S.5078',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/s5078.json',
#   'title': 'A bill to designate the facility of the United States Postal Service located at 123 East Main Street in Vergas, Minnesota, as the "Jon Glawe Post Office".',
#   'short_title': 'A bill to designate the facility of the United States Postal Service located at 123 East Main Street in Vergas, Minnesota, as the "Jon Glawe Post Office".',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'K000367',
#   'sponsor_name': 'Amy Klobuchar',
#   'sponsor_state': 'MN',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/K000367.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-bill/5078',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/s5078',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'D': 1},
#   'committees': 'Senate Homeland Security and Governmental Affairs Committee',
#   'committee_codes': ['SSGA'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': 'Designates the facility of the United States Postal Service located at 123 East Main Street in Vergas, Minnesota, as the "Jon Glawe Post Office."',
#   'summary_short': 'Designates the facility of the United States Postal Service located at 123 East Main Street in Vergas, Minnesota, as the &quot;Jon Glawe Post Office.&quot;',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#  {'_id': ObjectId('6373b28c984f175941eafbab'),
#   'bill_id': 'sjres64-117',
#   'bill_slug': 'sjres64',
#   'bill_type': 'sjres',
#   'number': 'S.J.RES.64',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/sjres64.json',
#   'title': 'A joint resolution disapproving of the rule submitted by the Department of Homeland Security relating to "Public Charge Ground of Inadmissibility".',
#   'short_title': 'A joint resolution disapproving of the rule submitted by the Department of Homeland Security relating to "Public Charge Ground of Inadmissibility".',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'M001198',
#   'sponsor_name': 'Roger Marshall',
#   'sponsor_state': 'KS',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/M001198.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-joint-resolution/64',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/sjres64',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'R': 1},
#   'committees': 'Senate Judiciary Committee',
#   'committee_codes': ['SSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Read twice and referred to the Committee on the Judiciary.'},
#  {'_id': ObjectId('6373b28c984f175941eafbac'),
#   'bill_id': 'hr9295-117',
#   'bill_slug': 'hr9295',
#   'bill_type': 'hr',
#   'number': 'H.R.9295',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9295.json',
#   'title': 'To amend the Alaska Native Claims Settlement Act to provide that Alexander Creek, Incorporated, is recognized as a Village Corporation under that Act, and for other purposes.',
#   'short_title': 'To amend the Alaska Native Claims Settlement Act to provide that Alexander Creek, Incorporated, is recognized as a Village Corporation under that Act, and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'P000619',
#   'sponsor_name': 'Mary Peltola',
#   'sponsor_state': 'AK',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/P000619.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9295',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9295',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Natural Resources Committee',
#   'committee_codes': ['HSII'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Natural Resources.'},
#  {'_id': ObjectId('6373b28c984f175941eafbad'),
#   'bill_id': 'hr9294-117',
#   'bill_slug': 'hr9294',
#   'bill_type': 'hr',
#   'number': 'H.R.9294',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9294.json',
#   'title': "To amend the Claims Resolution Act to make a technical correction to the Taos Pueblo Water Development Fund and the Aamodt Settlement Pueblos' Fund, and for other purposes.",
#   'short_title': "To amend the Claims Resolution Act to make a technical correction to the Taos Pueblo Water Development Fund and the Aamodt Settlement Pueblos' Fund, and for other purposes.",
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'L000273',
#   'sponsor_name': 'Teresa Leger Fernandez',
#   'sponsor_state': 'NM',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000273.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9294',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9294',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Natural Resources Committee',
#   'committee_codes': ['HSII'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Natural Resources.'},
#  {'_id': ObjectId('6373b28c984f175941eafbae'),
#   'bill_id': 'hr9296-117',
#   'bill_slug': 'hr9296',
#   'bill_type': 'hr',
#   'number': 'H.R.9296',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9296.json',
#   'title': 'To direct the Director of the Bureau of Prisons to conduct a comprehensive review of understaffing across the Bureau, and for other purposes.',
#   'short_title': 'To direct the Director of the Bureau of Prisons to conduct a comprehensive review of understaffing across the Bureau, and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'S001175',
#   'sponsor_name': 'Jackie Speier',
#   'sponsor_state': 'CA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/S001175.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9296',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9296',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 5,
#   'cosponsors_by_party': {'D': 3, 'R': 2},
#   'committees': 'House Judiciary Committee',
#   'committee_codes': ['HSJU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on the Judiciary.'},
#  {'_id': ObjectId('6373b28c984f175941eafbaf'),
#   'bill_id': 'hr9292-117',
#   'bill_slug': 'hr9292',
#   'bill_type': 'hr',
#   'number': 'H.R.9292',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9292.json',
#   'title': 'To promote United States interests at the international financial institutions, and for other purposes.',
#   'short_title': 'To promote United States interests at the international financial institutions, and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'H001072',
#   'sponsor_name': 'French Hill',
#   'sponsor_state': 'AR',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/H001072.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9292',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9292',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Financial Services Committee',
#   'committee_codes': ['HSBA'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Financial Services.'},
#  {'_id': ObjectId('6373b28c984f175941eafbb0'),
#   'bill_id': 'hr9291-117',
#   'bill_slug': 'hr9291',
#   'bill_type': 'hr',
#   'number': 'H.R.9291',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9291.json',
#   'title': 'To require a report on the death of Shireen Abu Akleh.',
#   'short_title': 'To require a report on the death of Shireen Abu Akleh.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'C001072',
#   'sponsor_name': 'André Carson',
#   'sponsor_state': 'IN',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/C001072.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9291',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9291',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 18,
#   'cosponsors_by_party': {'D': 18},
#   'committees': 'House Foreign Affairs Committee',
#   'committee_codes': ['HSFA'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Foreign Affairs.'},
#  {'_id': ObjectId('6373b28c984f175941eafbb1'),
#   'bill_id': 'hr9293-117',
#   'bill_slug': 'hr9293',
#   'bill_type': 'hr',
#   'number': 'H.R.9293',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hr9293.json',
#   'title': 'To amend the Omnibus Public Land Management Act of 2009 to make a technical correction to the Navajo Nation Water Resources Development Trust Fund, and for other purposes.',
#   'short_title': 'To amend the Omnibus Public Land Management Act of 2009 to make a technical correction to the Navajo Nation Water Resources Development Trust Fund, and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'L000273',
#   'sponsor_name': 'Teresa Leger Fernandez',
#   'sponsor_state': 'NM',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000273.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-bill/9293',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hr9293',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Natural Resources Committee',
#   'committee_codes': ['HSII'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Natural Resources.'},
#  {'_id': ObjectId('6373b28c984f175941eafbb2'),
#   'bill_id': 'hres1465-117',
#   'bill_slug': 'hres1465',
#   'bill_type': 'hres',
#   'number': 'H.RES.1465',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hres1465.json',
#   'title': 'Amending the Rules of the House of Representatives to prohibit the consideration of bills and resolutions whose titles do not adequately express their contents.',
#   'short_title': 'Amending the Rules of the House of Representatives to prohibit the consideration of bills and resolutions whose titles do not adequately express their contents.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'D000032',
#   'sponsor_name': 'Byron Donalds',
#   'sponsor_state': 'FL',
#   'sponsor_party': 'R',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/D000032.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-resolution/1465',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hres1465',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 2,
#   'cosponsors_by_party': {'R': 2},
#   'committees': 'House Rules Committee',
#   'committee_codes': ['HSRU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the House Committee on Rules.'},
#  {'_id': ObjectId('6373b28c984f175941eafbb3'),
#   'bill_id': 'hres1464-117',
#   'bill_slug': 'hres1464',
#   'bill_type': 'hres',
#   'number': 'H.RES.1464',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/hres1464.json',
#   'title': 'Providing for consideration of the bill (S. 4524) to limit the judicial enforceability of predispute nondisclosure and nondisparagement contract clauses relating to disputes involving sexual assault and sexual harassment; and for other purposes.',
#   'short_title': 'Providing for consideration of the bill (S. 4524) to limit the judicial enforceability of predispute nondisclosure and nondisparagement contract clauses relating to disputes involving sexual assault and sexual harassment; and for other purposes.',
#   'sponsor_title': 'Rep.',
#   'sponsor_id': 'S001205',
#   'sponsor_name': 'Mary Gay Scanlon',
#   'sponsor_state': 'PA',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/S001205.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/house-resolution/1464',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/hres1464',
#   'introduced_date': '2022-11-14',
#   'active': True,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 0,
#   'cosponsors_by_party': {},
#   'committees': 'House Rules Committee',
#   'committee_codes': ['HSRU'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': 'Sets forth the rule for consideration of the bill (S. 4524) to limit the judicial enforceability of predispute nondisclosure and nondisparagement contract clauses relating to disputes involving sexual assault and sexual harassment.',
#   'summary_short': 'Sets forth the rule for consideration of the bill (S. 4524) to limit the judicial enforceability of predispute nondisclosure and nondisparagement contract clauses relating to disputes involving sexual assault and sexual harassment.',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Placed on the House Calendar, Calendar No. 150.'}]

# %%
myquery = bills.find({'sponsor_name': 'Patrick J. Leahy'})
loads(dumps(myquery))
#just bills by patrick leahy
# Out:
# [{'_id': ObjectId('6373b28c984f175941eafba0'),
#   'bill_id': 'sres830-117',
#   'bill_slug': 'sres830',
#   'bill_type': 'sres',
#   'number': 'S.RES.830',
#   'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/sres830.json',
#   'title': 'A resolution expressing support for the designation of the week of October 24, 2022, to October 31, 2022, as "Bat Week".',
#   'short_title': 'A resolution expressing support for the designation of the week of October 24, 2022, to October 31, 2022, as "Bat Week".',
#   'sponsor_title': 'Sen.',
#   'sponsor_id': 'L000174',
#   'sponsor_name': 'Patrick J. Leahy',
#   'sponsor_state': 'VT',
#   'sponsor_party': 'D',
#   'sponsor_uri': 'https://api.propublica.org/congress/v1/members/L000174.json',
#   'gpo_pdf_uri': None,
#   'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-resolution/830',
#   'govtrack_url': 'https://www.govtrack.us/congress/bills/117/sres830',
#   'introduced_date': '2022-11-14',
#   'active': False,
#   'last_vote': None,
#   'house_passage': None,
#   'senate_passage': None,
#   'enacted': None,
#   'vetoed': None,
#   'cosponsors': 1,
#   'cosponsors_by_party': {'D': 1},
#   'committees': 'Senate Environment and Public Works Committee',
#   'committee_codes': ['SSEV'],
#   'subcommittee_codes': [],
#   'primary_subject': '',
#   'summary': '',
#   'summary_short': '',
#   'latest_major_action_date': '2022-11-14',
#   'latest_major_action': 'Referred to the Committee on Environment and Public Works.'}]

# %%
#find function has two arguments - first filters the rows, second filters the columns by setting them equal to 1 
myquery = bills.find({'sponsor_name': 'Patrick J. Leahy'}, {"_id":0,'number':1, 'sponsor_name':1, 'title':1})
loads(dumps(myquery))
#just bills by patrick leahy and we just want number, sponsor name, and title
# Out:
# [{'number': 'S.RES.830',
#   'title': 'A resolution expressing support for the designation of the week of October 24, 2022, to October 31, 2022, as "Bat Week".',
#   'sponsor_name': 'Patrick J. Leahy'}]

# %%
myquery = bills.find({}, {"_id":0,'number':1, 'sponsor_name':1, 'title':1})
pd.DataFrame.from_records(loads(dumps(myquery)))
#pull those columns for all rows and put in dataframe
# Out:
#         number                                              title  \
# 0    S.RES.830  A resolution expressing support for the design...
# 1       S.5082  A bill to impose sanctions with respect to Gen...
# 2       S.5077  A bill to amend the Alaska Native Claims Settl...
# 3       S.5081  A bill to establish an Office of Environmental...
# 4       S.5079  A bill to designate the facility of the United...
# 5       S.5076  A bill to require training for employees of Fe...
# 6       S.5080  A bill to direct the Secretary of Transportati...
# 7       S.5084  A bill to reprioritize Federal law enforcement...
# 8       S.5083  A bill to require the Secretary of State to su...
# 9       S.5085  A bill to prohibit the government of the Distr...
# 10      S.5078  A bill to designate the facility of the United...
# 11  S.J.RES.64  A joint resolution disapproving of the rule su...
# 12    H.R.9295  To amend the Alaska Native Claims Settlement A...
# 13    H.R.9294  To amend the Claims Resolution Act to make a t...
# 14    H.R.9296  To direct the Director of the Bureau of Prison...
# 15    H.R.9292  To promote United States interests at the inte...
# 16    H.R.9291  To require a report on the death of Shireen Ab...
# 17    H.R.9293  To amend the Omnibus Public Land Management Ac...
# 18  H.RES.1465  Amending the Rules of the House of Representat...
# 19  H.RES.1464  Providing for consideration of the bill (S. 45...
#
#               sponsor_name
# 0         Patrick J. Leahy
# 1            Joshua Hawley
# 2             Dan Sullivan
# 3             Alex Padilla
# 4            Amy Klobuchar
# 5               Joni Ernst
# 6       Richard Blumenthal
# 7             Bill Hagerty
# 8          Robert Menendez
# 9                 Ted Cruz
# 10           Amy Klobuchar
# 11          Roger Marshall
# 12            Mary Peltola
# 13  Teresa Leger Fernandez
# 14           Jackie Speier
# 15             French Hill
# 16            André Carson
# 17  Teresa Leger Fernandez
# 18           Byron Donalds
# 19        Mary Gay Scanlon

# %%
#see if any bills have more than 0 cosponsors- it pulls all of them - full list of operators is in the textbook
myquery = bills.find({'cosponsors': {'$gt':0}}, {"_id":0,'number':1, 'sponsor_name':1, 'title':1, 'cosponsors':1})
pd.DataFrame.from_records(loads(dumps(myquery)))
# Out:
#         number                                              title  \
# 0    S.RES.830  A resolution expressing support for the design...
# 1       S.5081  A bill to establish an Office of Environmental...
# 2       S.5079  A bill to designate the facility of the United...
# 3       S.5076  A bill to require training for employees of Fe...
# 4       S.5084  A bill to reprioritize Federal law enforcement...
# 5       S.5083  A bill to require the Secretary of State to su...
# 6       S.5078  A bill to designate the facility of the United...
# 7   S.J.RES.64  A joint resolution disapproving of the rule su...
# 8     H.R.9296  To direct the Director of the Bureau of Prison...
# 9     H.R.9291  To require a report on the death of Shireen Ab...
# 10  H.RES.1465  Amending the Rules of the House of Representat...
#
#         sponsor_name  cosponsors
# 0   Patrick J. Leahy           1
# 1       Alex Padilla           7
# 2      Amy Klobuchar           1
# 3         Joni Ernst           2
# 4       Bill Hagerty           5
# 5    Robert Menendez           2
# 6      Amy Klobuchar           1
# 7     Roger Marshall           1
# 8      Jackie Speier           5
# 9       André Carson          18
# 10     Byron Donalds           2

# %%
#text search - search in summary column for all text 
bills.create_index(['summary', 'text'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [41], line 2
#       1 #text search - search in summary column for all text
# ----> 2 bills.create_index(['summary', 'text'])
#
# File /usr/local/lib/python3.11/site-packages/pymongo/collection.py:2047, in Collection.create_index(self, keys, session, comment, **kwargs)
#    2045 if comment is not None:
#    2046     cmd_options["comment"] = comment
# -> 2047 index = IndexModel(keys, **kwargs)
#    2048 return self.__create_indexes([index], session, **cmd_options)[0]
#
# File /usr/local/lib/python3.11/site-packages/pymongo/operations.py:495, in IndexModel.__init__(self, keys, **kwargs)
#     493 keys = _index_list(keys)
#     494 if "name" not in kwargs:
# --> 495     kwargs["name"] = _gen_index_name(keys)
#     496 kwargs["key"] = _index_document(keys)
#     497 collation = validate_collation_or_none(kwargs.pop("collation", None))
#
# File /usr/local/lib/python3.11/site-packages/pymongo/helpers.py:74, in _gen_index_name(keys)
#      72 def _gen_index_name(keys):
#      73     """Generate an index name from the set of fields it is over."""
# ---> 74     return "_".join(["%s_%s" % item for item in keys])
#
# File /usr/local/lib/python3.11/site-packages/pymongo/helpers.py:74, in <listcomp>(.0)
#      72 def _gen_index_name(keys):
#      73     """Generate an index name from the set of fields it is over."""
# ---> 74     return "_".join(["%s_%s" % item for item in keys])
#
# TypeError: not enough arguments for format string
