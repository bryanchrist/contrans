# %%
import pandas as pd
import numpy as np

# %%
memideo_url = "https://voteview.com/static/data/out/members/HSall_members.csv"
cvotes_url = "https://voteview.com/static/data/out/rollcalls/HSall_rollcalls.csv"
memvotes_url = "https://voteview.com/static/data/out/votes/HSall_votes.csv"
cparties_url = "https://voteview.com/static/data/out/parties/HSall_parties.csv"

# %%
memideo = pd.read_csv(memideo_url)
cvotes= pd.read_csv(cvotes_url)
memvotes = pd.read_csv(memvotes_url)
cparties = pd.read_csv(cparties_url)
# Out:
# /tmp/ipykernel_14/2030979840.py:2: DtypeWarning: Columns (14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   cvotes= pd.read_csv(cvotes_url)

# %%
cvotes
# Out:
#         congress chamber  rollnumber        date  session  clerk_rollnumber  \
# 0              1   House           1  1789-05-16      NaN               NaN
# 1              1   House           2  1789-05-22      NaN               NaN
# 2              1   House           3  1789-06-22      NaN               NaN
# 3              1   House           4  1789-06-22      NaN               NaN
# 4              1   House           5  1789-06-24      NaN               NaN
# ...          ...     ...         ...         ...      ...               ...
# 109826       117  Senate         852  2022-08-07      2.0             324.0
# 109827       117  Senate         853  2022-08-07      2.0             325.0
# 109828       117  Senate         854  2022-09-06      2.0             326.0
# 109829       117  Senate         855  2022-09-07      2.0             327.0
# 109830       117  Senate         856  2022-09-07      2.0             328.0
#
#         yea_count  nay_count  nominate_mid_1  nominate_mid_2  \
# 0              41          8           0.484          -0.872
# 1              36          1           0.256           0.967
# 2              30         18          -0.394          -0.454
# 3              31         19          -0.194          -0.981
# 4              29         22          -0.197          -0.266
# ...           ...        ...             ...             ...
# 109826         50         50           0.042          -0.077
# 109827         50         50           0.042          -0.077
# 109828         48         42          -0.112           0.935
# 109829         50         44          -0.111           0.926
# 109830         48         45          -0.151          -0.989
#
#         nominate_spread_1  nominate_spread_2  nominate_log_likelihood  \
# 0                   0.229             -0.378                  -13.144
# 1                  -0.090              1.791                   -1.900
# 2                  -0.176              0.922                  -22.048
# 3                   0.081             -0.327                  -30.355
# 4                  -0.168              0.984                  -22.221
# ...                   ...                ...                      ...
# 109826              0.677             -0.559                   -0.142
# 109827              0.677             -0.559                   -0.142
# 109828              0.508              0.998                   -7.606
# 109829              0.509              1.007                   -7.614
# 109830              0.359             -0.456                   -6.998
#
#        bill_number               vote_result  \
# 0              HR2                       NaN
# 1              NaN                       NaN
# 2              HR8                       NaN
# 3              HR8                       NaN
# 4              HR8                       NaN
# ...            ...                       ...
# 109826      HR5376       Amendment Agreed to
# 109827      HR5376               Bill Passed
# 109828      PN1965  Cloture Motion Agreed to
# 109829      PN1965      Nomination Confirmed
# 109830      PN1502  Cloture Motion Agreed to
#
#                                                 vote_desc  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 109826  To strike the extension of the limitation on S...
# 109827  A bill to provide for reconciliation pursuant ...
# 109828  John Z. Lee, of Illinois, to be United States ...
# 109829  John Z. Lee, of Illinois, to be United States ...
# 109830  Andre B. Mathis, of Tennessee, to be United St...
#
#                  vote_question  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 109826        On the Amendment
# 109827  On Passage of the Bill
# 109828   On the Cloture Motion
# 109829       On the Nomination
# 109830   On the Cloture Motion
#
#                                                  dtl_desc
# 0       TO AMEND H.R. 2, (1 STAT. 24, APP. 7-4-1789), ...
# 1       TO PASS THE RESOLUTION THAT IT APPEARS TO THIS...
# 2       TO AMEND H.R. 8, (1 STAT. 28, APP. 7-27-1789),...
# 3       TO AMEND H.R. 8, SO AS TO ELIMINATE THE PRESID...
# 4                                         TO PASS H.R. 8.
# ...                                                   ...
# 109826                                                NaN
# 109827                                                NaN
# 109828                                                NaN
# 109829                                                NaN
# 109830                                                NaN
#
# [109831 rows x 18 columns]

# %%
cparties
# Out:
#      congress    chamber  party_code           party_name  n_members  \
# 0           1  President        5000   Pro-Administration          1
# 1           1      House        4000  Anti-Administration         29
# 2           1      House        5000   Pro-Administration         37
# 3           1     Senate        4000  Anti-Administration          9
# 4           1     Senate        5000   Pro-Administration         20
# ..        ...        ...         ...                  ...        ...
# 830       117      House         100             Democrat        230
# 831       117      House         200           Republican        221
# 832       117     Senate         100             Democrat         49
# 833       117     Senate         200           Republican         51
# 834       117     Senate         328          Independent          2
#
#      nominate_dim1_median  nominate_dim2_median  nominate_dim1_mean  \
# 0                     NaN                   NaN                 NaN
# 1                  0.0180                0.0920           -0.024379
# 2                  0.5780                0.0570            0.527838
# 3                 -0.2375               -0.2130           -0.239750
# 4                  0.4270               -0.3085            0.352050
# ..                    ...                   ...                 ...
# 830               -0.3810               -0.0245           -0.381087
# 831                0.5000                0.1155            0.503259
# 832               -0.3480               -0.1230           -0.348490
# 833                0.4980                0.0090            0.523980
# 834               -0.3490               -0.2990           -0.349000
#
#      nominate_dim2_mean
# 0                   NaN
# 1              0.141931
# 2              0.025757
# 3             -0.044750
# 4             -0.166200
# ..                  ...
# 830           -0.029387
# 831            0.073441
# 832           -0.104286
# 833            0.020118
# 834           -0.299000
#
# [835 rows x 9 columns]
